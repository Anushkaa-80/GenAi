# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# !pip install diffusers
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 9.8 MB/s eta 0:00:00
# ...

# %%
## Environment secret keys
from google.colab import userdata
import os
sec_key=userdata.get("HF_TOKEN")
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key
print(sec_key)
if sec_key:
    print("Hugging Face token successfully retrieved.")
else:
    print("Hugging Face token not found. Please set your token.")
# Out:
# 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
# Hugging Face token successfully retrieved.

# %% [markdown]
# ## HuggingFaceEndpoint
# ## How to Access HuggingFace Models with API
# There are also two ways to use this class. You can specify the model with the repo_id parameter. Those endpoints use the serverless API, which is particularly beneficial to people using pro accounts or enterprise hub. Still, regular users can already have access to a fair amount of request by connecting with their HF token in the environment where they are executing the code.

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,temperature=0.5,model_kwargs={"max_length":200,"token":sec_key})
print(llm)
# Out:
# HuggingFaceEndpoint
# Params: {'endpoint_url': None, 'task': None, 'model_kwargs': {'max_length': 200, 'token': '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'}}

# %%
llm.invoke("What is machine learning")
# Out:
# '?\n\nMachine learning is a type of artificial intelligence (AI) that allows computers to learn from data, without being explicitly programmed. It involves training algorithms to recognize patterns and make decisions based on that training.\n\nThere are several types of machine learning, including supervised learning, unsupervised learning, and reinforcement learning. In supervised learning, the algorithm is trained on a labeled dataset, where the correct answer is provided for each example. In unsupervised learning, the algorithm is given an unlabeled dataset and must find patterns on its own. Reinforcement learning involves an agent learning to take actions in an environment to maximize a reward.\n\nMachine learning is used in a wide variety of applications, including image and speech recognition, natural language processing, fraud detection, and predictive analytics. It has the potential to revolutionize many industries, from healthcare to finance to transportation.\n\nWhy is mach
# ...

# %%
llm.invoke("What is Genertaive AI")
# Out:
# ' and How it Works?\n\nGenerative AI is a type of artificial intelligence that is capable of creating new content, such as images, videos, music, or text, based on patterns it has learned from existing data. It differs from other types of AI, such as discriminative AI, which is designed to make decisions or classify data based on given examples.\n\nGenerative AI works by using a statistical model to generate new data that is similar to the data it was trained on. This is typically done using techniques such as deep learning, which involves training a neural network on large amounts of data. The neural network learns to recognize patterns in the data and can then use those patterns to generate new data that is similar to the original data.\n\nOne common application of generative AI is in the field of computer graphics, where it is used to create realistic images, videos, and animations. For example, a generative AI model could be trained on a large dataset of photographs of people, an
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="Who won the Cricket World Cup in the year 2011?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
final_chain=prompt|llm

print(final_chain.invoke(question))
# Out:
# The Cricket World Cup is a quadrennial international tournament for One Day International (ODI) cricket. The first World Cup was held in 1975.
#
# To find the winner of the World Cup in the year 2011, we need to look for the World Cup that was held in that year. The 2011 Cricket World Cup was held in India, Sri Lanka, and Bangladesh.
#
# The final match of the 2011 World Cup was played on April 2, 2011, between India and Sri Lanka. Unfortunately, India lost to Sri Lanka. However, the 2011 World Cup was not won by India but by Sri Lanka.
#
# So, Sri Lanka won the Cricket World Cup in the year 2011.

# %% [markdown]
# ## HuggingFacePipeline
# Among transformers, the Pipeline is the most versatile tool in the Hugging Face toolbox. LangChain being designed primarily to address RAG and Agent use cases, the scope of the pipeline here is reduced to the following text-centric tasks: “text-generation", “text2text-generation", “summarization”, “translation”.
# Models can be loaded directly with the from_model_id method

# %%
from langchain import PromptTemplate, LLMChain

question="What is Auto Encoder?"
template = """Question: {question}
Answer: here is your answer."""
prompt = PromptTemplate(template=template, input_variables=["question"])
final_chain=prompt|llm

print(final_chain.invoke(question))
# Out:
# Autoencoders are a type of artificial neural network used for learning efficient codings of input data. They are trained to reconstruct their input data, which forces them to learn a compact and informative representation of the input data.
#
# An autoencoder consists of two main parts: an encoder and a decoder. The encoder takes the input data and maps it to a lower-dimensional representation, called the bottleneck or latent representation. The decoder then takes the bottleneck representation and maps it back to the original input data.
#
# During training, the autoencoder is trained to minimize the difference between its input and output, typically using a loss function such as mean squared error or cross-entropy. This forces the autoencoder to learn an efficient and informative representation of the input data.
#
# ...

# %%
question="What is Data Structure?"

prompt = PromptTemplate(template=template, input_variables=["question"])
final_chain=prompt|llm

print(final_chain.invoke(question))
# Out:
# A data structure is a specialized format for organizing, processing, retrieving, and storing data in a computer system. It defines the way in which data is stored, accessed, and manipulated in a computer program.
#
# Data structures provide a way to organize and manage data efficiently, allowing for faster and easier access, manipulation, and processing. They are essential for developing efficient and scalable software applications.
#
# There are many types of data structures, including arrays, linked lists, stacks, queues, trees, graphs, and hash tables. Each data structure has its own strengths and weaknesses, and is suited for different types of problems and use cases.
#
# Understanding data structures is an important part of learning computer programming, and is essential for developing efficient and effective software solutions.

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=200)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7ec5898590f0>, model_id='gpt2')

# %%
from diffusers import StableDiffusionPipeline

# Load the Stable Diffusion pipeline for image generation
image_pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    use_auth_token=sec_key
)
image_pipe.to("cuda")  # Use GPU for faster generation if available
# Out:
# WARNING:bitsandbytes.cextension:The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# ...

# %%
import matplotlib.pyplot as plt

def generate_image_from_chatbot(query):
    """
    Combines chatbot text generation and image generation.
    :param query: The input text for the chatbot.
    :return: Generated image based on the chatbot's response.
    """
    # Step 1: Get chatbot response
    chatbot_response = hf.invoke(query)
    print(f"Chatbot Response: {chatbot_response}")

    # Step 2: Generate image from chatbot response
    print("Generating image...")
    image = image_pipe(chatbot_response).images[0]

    # Step 3: Display the generated image
    plt.figure(figsize=(8, 8))
    plt.imshow(image)
    plt.axis("off")
    plt.title("Generated Image Based on Chatbot Response")
    plt.show()

# %%
# Example query
query = "Describe a peaceful forest with sunlight filtering through the trees."

# Generate image from the chatbot's response
generate_image_from_chatbot(query)

# %%
# Example query
query = "A beautiful flower."

# Generate image from the chatbot's response
generate_image_from_chatbot(query)

# %%
hf.invoke("What is neural network")

# %%
## Use HuggingfacePipelines With Gpu
gpu_llm = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    device=-1,  # replace with device_map="auto" to use the accelerate library.
    pipeline_kwargs={"max_new_tokens": 100},
)

# %%
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's think step by step."""
prompt = PromptTemplate.from_template(template)

# %%
chain=prompt|gpu_llm

# %%
question="What is artificial intelligence?"
chain.invoke({"question":question})

# %%
# Example query
query = "a beautiful sunset"

# Generate image from the chatbot's response
generate_image_from_chatbot(query)

# %%
question="climate change in india?"
chain.invoke({"question":question})

# %%
# Example query
query = "BURJ KHALIFA"

# Generate image from the chatbot's response
generate_image_from_chatbot(query)

# %%
# Example query
query = "scenic beautiful view"

# Generate image from the chatbot's response
generate_image_from_chatbot(query)
